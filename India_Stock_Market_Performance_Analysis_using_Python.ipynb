# %% [markdown]
# <a href="https://colab.research.google.com/github/ommishra0707/Indian-stock-market-performance-analysis/blob/main/India_Stock_Market_Performance_Analysis_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # India Market Performance Analysis using Python

# %% [markdown]
# Stock Market Performance Analysis involves calculating moving averages, measuring volatility, conducting correlation analysis and analyzing various aspects of the stock market to gain a deeper understanding of the factors that affect stock prices and the relationships between the stock prices of different companies.

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
start_date = datetime.now() - pd.DateOffset(months=3)
end_date = datetime.now()

# %%
tickers = ['HDFCBANK.NS', 'RELIANCE.NS', 'TCS.NS', 'HINDUNILVR.NS']

# %%
df_list = []

# %%
for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date)
    df_list.append(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.concat(df_list, keys=tickers, names=['Ticker', 'Date'])
print(df.head())
# Out:
#                                Open         High          Low        Close  \
# Ticker      Date
# HDFCBANK.NS 2023-04-10  1663.250000  1671.000000  1654.000000  1658.449951
#             2023-04-11  1659.000000  1669.400024  1651.099976  1663.300049
#             2023-04-12  1668.000000  1688.199951  1667.800049  1684.900024
#             2023-04-13  1688.300049  1697.050049  1678.150024  1692.449951
#             2023-04-17  1720.000000  1720.000000  1653.300049  1666.650024
#
#                           Adj Close    Volume
# Ticker      Date
# HDFCBANK.NS 2023-04-10  1639.646606  15906643
#             2023-04-11  1644.441772  21180771
#             2023-04-12  1665.796875  13477752
#             2023-04-13  1673.261108  17665043
#             2023-04-17  1647.753784  16202574

# %%
df = df.reset_index()
print(df.head())
# Out:
#         Ticker       Date         Open         High          Low        Close  \
# 0  HDFCBANK.NS 2023-04-10  1663.250000  1671.000000  1654.000000  1658.449951
# 1  HDFCBANK.NS 2023-04-11  1659.000000  1669.400024  1651.099976  1663.300049
# 2  HDFCBANK.NS 2023-04-12  1668.000000  1688.199951  1667.800049  1684.900024
# 3  HDFCBANK.NS 2023-04-13  1688.300049  1697.050049  1678.150024  1692.449951
# 4  HDFCBANK.NS 2023-04-17  1720.000000  1720.000000  1653.300049  1666.650024
#
#      Adj Close    Volume
# 0  1639.646606  15906643
# 1  1644.441772  21180771
# 2  1665.796875  13477752
# 3  1673.261108  17665043
# 4  1647.753784  16202574

# %%
import plotly.express as px
fig = px.line(df, x='Date',
              y='Close',
              color='Ticker',
              title="Stock Market Performance for the Last 3 Months")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="601bfe29-7b34-473e-a345-62c860393ab1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("601bfe29-7b34-473e-a345-62c860393ab1")) {                    Plotly.newPlot(                        "601bfe29-7b34-473e-a345-62c860393ab1",                        [{"hovertemplate":"Ticker=HDFCBANK.NS<br>Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"HDFCBANK.NS","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HDFCBANK.NS","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[1658.449951171875,1663.300048828125,1684.9000244140625,1692.449951171875,1666.6500244140625,1659.5999755859375,1665.699951171875,1671.9000244140625,1674.5999755859375,1688.1500244140625,1664.1500244140625,1671.800048828125,1681.0,1687.5999755859375,1687.25,1693.1500244140625,1727.800048828125,1625.6500244140625,1644.449951171875,1644.5,1652.0999755859375,1653.199951171875,1667.800048828125,1675.800048828125,1647.300048828125,1638.449951171875,1645.0,1646.9000244140625,1641.050048828125,1637.199951171875,1615.800048828125,1609.5999755859375,1615.800048828125,1635.5,1636.75,1610.8499755859375,1604.0,1606.5,1604.4000244140625,1599.4000244140625,1607.699951171875,1608.699951171875,1610.5999755859375,1600.800048828125,1603.5,1601.75,1582.050048828125,1602.75,1604.1500244140625,1607.5,1635.5999755859375,1643.5999755859375,1643.5,1635.550048828125,1658.5999755859375,1658.5999755859375,1701.4000244140625,1719.800048828125,1728.199951171875,1673.300048828125,1675.0,1660.4000244140625],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=RELIANCE.NS<br>Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"RELIANCE.NS","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RELIANCE.NS","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05- ...

# %%
fig = px.area(df, x='Date', y='Close', color='Ticker',
              facet_col='Ticker',
              labels={'Date':'Date', 'Close':'Closing Price', 'Ticker':'Company'},
              title='Stock Prices for HDFC BANK, RELIANCE, TCS, and HINDUNILVR')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f0d4108d-2d6b-4fa0-8c28-f3765456789d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0d4108d-2d6b-4fa0-8c28-f3765456789d")) {                    Plotly.newPlot(                        "f0d4108d-2d6b-4fa0-8c28-f3765456789d",                        [{"fillpattern":{"shape":""},"hovertemplate":"Company=HDFCBANK.NS<br>Date=%{x}<br>Closing Price=%{y}<extra></extra>","legendgroup":"HDFCBANK.NS","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"HDFCBANK.NS","orientation":"v","showlegend":true,"stackgroup":"1","x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[1658.449951171875,1663.300048828125,1684.9000244140625,1692.449951171875,1666.6500244140625,1659.5999755859375,1665.699951171875,1671.9000244140625,1674.5999755859375,1688.1500244140625,1664.1500244140625,1671.800048828125,1681.0,1687.5999755859375,1687.25,1693.1500244140625,1727.800048828125,1625.6500244140625,1644.449951171875,1644.5,1652.0999755859375,1653.199951171875,1667.800048828125,1675.800048828125,1647.300048828125,1638.449951171875,1645.0,1646.9000244140625,1641.050048828125,1637.199951171875,1615.800048828125,1609.5999755859375,1615.800048828125,1635.5,1636.75,1610.8499755859375,1604.0,1606.5,1604.4000244140625,1599.4000244140625,1607.699951171875,1608.699951171875,1610.5999755859375,1600.800048828125,1603.5,1601.75,1582.050048828125,1602.75,1604.1500244140625,1607.5,1635.5999755859375,1643.5999755859375,1643.5,1635.550048828125,1658.5999755859375,1658.5999755859375,1701.4000244140625,1719.800048828125,1728.199951171875,1673.300048828125,1675.0,1660.4000244140625],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Company=RELIANCE.NS<br>Date=%{x}<br>Closing Price=%{y}<extra></extra>","legendgroup":"RELIANCE.NS","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"RELIANCE.NS","orientation":"v","showlegend":true,"stackgroup":"1","x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00" ...

# %%
df['MA10'] = df.groupby('Ticker')['Close'].rolling(window=10).mean().reset_index(0, drop=True)
df['MA20'] = df.groupby('Ticker')['Close'].rolling(window=20).mean().reset_index(0, drop=True)

for ticker, group in df.groupby('Ticker'):
    print(f'Moving Averages for {ticker}')
    print(group[['MA10', 'MA20']])
# Out:
# Moving Averages for HDFCBANK.NS
#            MA10         MA20
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 57  1650.830005  1626.497504
# 58  1663.234998  1632.687500
# 59  1669.815002  1636.382501
# 60  1673.755005  1639.747504
# 61  1675.435010  1642.332507
#
# [62 rows x 2 columns]
# Moving Averages for HINDUNILVR.NS
#             MA10         MA20
# 186          NaN          NaN
# 187          NaN          NaN
# 188          NaN          NaN
# 189          NaN          NaN
# 190          NaN          NaN
# ..           ...          ...
# 243  2666.590063  2675.430005
# 244  2668.265063  2675.640002
# 245  2676.240063  2678.875012
# 246  2684.290063  2680.920020
# 247  2688.665063  2681.830029
#
# [62 rows x 2 columns]
# Moving Averages for RELIANCE.NS
#             MA10         MA20
# 62           NaN          NaN
# 63           NaN          NaN
# 64           NaN          NaN
# 65           NaN          NaN
# 66           NaN          NaN
# ..           ...          ...
# 119  2537.785010  2525.050000
# 120  2541.480005  2530.625000
# 121  2544.219995  2535.882495
# 122  2551.664990  2542.912500
# 123  2561.475000  2549.610010
#
# [62 rows x 2 columns]
# Moving Averages for TCS.NS
#             MA10         MA20
# 124          NaN          NaN
# 125          NaN          NaN
# 126          NaN          NaN
# 127          NaN          NaN
# 128          NaN          NaN
# ..           ...          ...
# 181  3231.005005  3234.237488
# 182  3240.850024  3235.234998
# 183  3250.075024  3239.617493
# 184  3256.545020  3242.017493
# 185  3265.620020  3246.657495
#
# [62 rows x 2 columns]

# %%
for ticker, group in df.groupby('Ticker'):
    fig = px.line(group, x='Date', y=['Close', 'MA10', 'MA20'],
                  title=f"{ticker} Moving Averages")
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6ae2fe07-dcb0-44e7-a34b-72d32de55400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ae2fe07-dcb0-44e7-a34b-72d32de55400")) {                    Plotly.newPlot(                        "6ae2fe07-dcb0-44e7-a34b-72d32de55400",                        [{"hovertemplate":"variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[1658.449951171875,1663.300048828125,1684.9000244140625,1692.449951171875,1666.6500244140625,1659.5999755859375,1665.699951171875,1671.9000244140625,1674.5999755859375,1688.1500244140625,1664.1500244140625,1671.800048828125,1681.0,1687.5999755859375,1687.25,1693.1500244140625,1727.800048828125,1625.6500244140625,1644.449951171875,1644.5,1652.0999755859375,1653.199951171875,1667.800048828125,1675.800048828125,1647.300048828125,1638.449951171875,1645.0,1646.9000244140625,1641.050048828125,1637.199951171875,1615.800048828125,1609.5999755859375,1615.800048828125,1635.5,1636.75,1610.8499755859375,1604.0,1606.5,1604.4000244140625,1599.4000244140625,1607.699951171875,1608.699951171875,1610.5999755859375,1600.800048828125,1603.5,1601.75,1582.050048828125,1602.75,1604.1500244140625,1607.5,1635.5999755859375,1643.5999755859375,1643.5,1635.550048828125,1658.5999755859375,1658.5999755859375,1701.4000244140625,1719.800048828125,1728.199951171875,1673.300048828125,1675.0,1660.4000244140625],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=MA10<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"MA10","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MA10","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4d79e894-cfc2-46dc-bfc6-e771327ec407" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d79e894-cfc2-46dc-bfc6-e771327ec407")) {                    Plotly.newPlot(                        "4d79e894-cfc2-46dc-bfc6-e771327ec407",                        [{"hovertemplate":"variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[2532.14990234375,2547.75,2528.949951171875,2536.199951171875,2551.85009765625,2541.050048828125,2531.60009765625,2492.60009765625,2497.949951171875,2499.75,2490.449951171875,2510.800048828125,2468.949951171875,2457.300048828125,2451.699951171875,2486.0,2506.75,2500.75,2516.300048828125,2515.800048828125,2522.699951171875,2592.39990234375,2623.39990234375,2662.25,2675.89990234375,2661.75,2627.550048828125,2641.449951171875,2638.10009765625,2628.300048828125,2614.949951171875,2597.25,2652.35009765625,2650.300048828125,2656.550048828125,2667.550048828125,2697.89990234375,2716.699951171875,2695.800048828125,2691.14990234375,2716.199951171875,2679.89990234375,2636.199951171875,2643.449951171875,2675.89990234375,2698.75,2689.699951171875,2715.64990234375,2683.25,2676.10009765625,2676.60009765625,2654.35009765625,2641.60009765625,2652.10009765625,2651.35009765625,2651.35009765625,2678.14990234375,2701.050048828125,2700.0,2755.85009765625,2757.10009765625,2698.10009765625],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=MA10<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"MA10","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MA10","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3f21411a-0ab4-40d2-a7f4-7c9895b19c94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f21411a-0ab4-40d2-a7f4-7c9895b19c94")) {                    Plotly.newPlot(                        "3f21411a-0ab4-40d2-a7f4-7c9895b19c94",                        [{"hovertemplate":"variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[2324.85009765625,2336.35009765625,2346.64990234375,2355.5,2367.449951171875,2340.35009765625,2352.0,2346.050048828125,2349.0,2358.0,2376.050048828125,2362.10009765625,2377.050048828125,2420.5,2441.050048828125,2420.10009765625,2448.0,2441.75,2471.89990234375,2479.550048828125,2496.60009765625,2480.300048828125,2484.35009765625,2489.25,2453.800048828125,2439.300048828125,2434.050048828125,2441.949951171875,2455.0,2454.550048828125,2440.25,2439.949951171875,2506.5,2520.60009765625,2519.949951171875,2469.89990234375,2463.25,2455.199951171875,2477.25,2479.35009765625,2498.14990234375,2499.64990234375,2481.949951171875,2484.14990234375,2520.85009765625,2551.85009765625,2552.550048828125,2577.39990234375,2551.800048828125,2557.10009765625,2564.300048828125,2535.5,2514.75,2495.550048828125,2496.449951171875,2496.449951171875,2550.25,2615.699951171875,2588.75,2584.5,2638.75,2633.60009765625],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=MA10<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"MA10","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MA10","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023- ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3b63d565-95dc-40b4-8d33-501805a3d064" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b63d565-95dc-40b4-8d33-501805a3d064")) {                    Plotly.newPlot(                        "3b63d565-95dc-40b4-8d33-501805a3d064",                        [{"hovertemplate":"variable=Close<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[3263.39990234375,3213.800048828125,3241.64990234375,3188.85009765625,3139.5,3130.75,3089.60009765625,3104.800048828125,3160.85009765625,3174.800048828125,3176.0,3198.14990234375,3187.949951171875,3219.25,3219.39990234375,3179.89990234375,3220.699951171875,3230.699951171875,3250.60009765625,3283.25,3286.800048828125,3282.14990234375,3274.300048828125,3255.050048828125,3258.14990234375,3208.699951171875,3199.85009765625,3222.85009765625,3298.699951171875,3297.050048828125,3303.35009765625,3293.5,3328.89990234375,3320.35009765625,3316.199951171875,3289.5,3324.0,3305.60009765625,3288.89990234375,3232.300048828125,3274.89990234375,3236.449951171875,3209.300048828125,3246.89990234375,3243.699951171875,3251.050048828125,3216.300048828125,3174.89990234375,3210.39990234375,3227.699951171875,3258.199951171875,3238.5,3216.35009765625,3189.64990234375,3197.35009765625,3197.35009765625,3302.25,3272.300048828125,3308.85009765625,3319.949951171875,3322.89990234375,3329.25],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=MA10<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"MA10","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"MA10","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00: ...

# %%
df['Volatility'] = df.groupby('Ticker')['Close'].pct_change().rolling(window=10).std().reset_index(0, drop=True)
fig = px.line(df, x='Date', y='Volatility',
              color='Ticker',
              title='Volatility of All Companies')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a7c713ec-70fa-4afc-8f55-3ffd2bbd6b7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7c713ec-70fa-4afc-8f55-3ffd2bbd6b7c")) {                    Plotly.newPlot(                        "a7c713ec-70fa-4afc-8f55-3ffd2bbd6b7c",                        [{"hovertemplate":"Ticker=HDFCBANK.NS<br>Date=%{x}<br>Volatility=%{y}<extra></extra>","legendgroup":"HDFCBANK.NS","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HDFCBANK.NS","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-30T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00"],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,0.009090064416910702,0.00915720997628013,0.008292765576432565,0.00825976035661987,0.006383680684547257,0.006108698452997035,0.0084663928218483,0.021593780904433812,0.022033550812976862,0.02178605469765145,0.02146243918450531,0.021394348955701376,0.02153058427422946,0.021552544025857098,0.022174202982161256,0.02209980324179897,0.020723401286578395,0.007988243602530243,0.00723031391067024,0.007261499235915236,0.00801291527660023,0.007960942575950902,0.007291219587911056,0.008465913751425143,0.006750135257002436,0.008217158544891544,0.007996423383405988,0.008017864216324083,0.008015054679481402,0.008020025714231918,0.007346728826865152,0.007254947132694917,0.007144389383878949,0.005806262653348537,0.005864328599820507,0.003309101529941197,0.004901522601545636,0.006693271639583005,0.006689203647723775,0.006621528033256378,0.008467112006501475,0.00851119908724429,0.008536434674608,0.008412457294617627,0.009208517198833914,0.009155393659112087,0.009745136626354659,0.00962218930672194,0.009414479506723446,0.015623228795652446,0.014911333869836237,0.01528349025478939],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=RELIANCE.NS<br>Date=%{x}<br>Volatility=%{y}<extra></extra>","legendgroup":"RELIANCE.NS","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RELIANCE.NS","orientation":"v","showlegend":true,"x":["2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00 ...

# %%
# create a DataFrame with the stock prices of HDFC_BANK and RELIANCE
HDFC_BANK = df.loc[df['Ticker'] == 'HDFCBANK.NS', ['Date', 'Close']].rename(columns={'Close': 'HDFCBANK.NS'})
RELIANCE= df.loc[df['Ticker'] == 'RELIANCE.NS', ['Date', 'Close']].rename(columns={'Close': 'RELIANCE'})
df_corr = pd.merge(HDFC_BANK, RELIANCE, on='Date')

# create a scatter plot to visualize the correlation
fig = px.scatter(df_corr, x='HDFCBANK.NS', y='RELIANCE',
                 trendline='ols',
                 title='Correlation between HDFCBANK and RELIANCE')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="56e296ba-da32-4473-b545-073d46b25456" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56e296ba-da32-4473-b545-073d46b25456")) {                    Plotly.newPlot(                        "56e296ba-da32-4473-b545-073d46b25456",                        [{"hovertemplate":"HDFCBANK.NS=%{x}<br>RELIANCE=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1658.449951171875,1663.300048828125,1684.9000244140625,1692.449951171875,1666.6500244140625,1659.5999755859375,1665.699951171875,1671.9000244140625,1674.5999755859375,1688.1500244140625,1664.1500244140625,1671.800048828125,1681.0,1687.5999755859375,1687.25,1693.1500244140625,1727.800048828125,1625.6500244140625,1644.449951171875,1644.5,1652.0999755859375,1653.199951171875,1667.800048828125,1675.800048828125,1647.300048828125,1638.449951171875,1645.0,1646.9000244140625,1641.050048828125,1637.199951171875,1615.800048828125,1609.5999755859375,1615.800048828125,1635.5,1636.75,1610.8499755859375,1604.0,1606.5,1604.4000244140625,1599.4000244140625,1607.699951171875,1608.699951171875,1610.5999755859375,1600.800048828125,1603.5,1601.75,1582.050048828125,1602.75,1604.1500244140625,1607.5,1635.5999755859375,1643.5999755859375,1643.5,1635.550048828125,1658.5999755859375,1658.5999755859375,1701.4000244140625,1719.800048828125,1728.199951171875,1673.300048828125,1675.0,1660.4000244140625],"xaxis":"x","y":[2324.85009765625,2336.35009765625,2346.64990234375,2355.5,2367.449951171875,2340.35009765625,2352.0,2346.050048828125,2349.0,2358.0,2376.050048828125,2362.10009765625,2377.050048828125,2420.5,2441.050048828125,2420.10009765625,2448.0,2441.75,2471.89990234375,2479.550048828125,2496.60009765625,2480.300048828125,2484.35009765625,2489.25,2453.800048828125,2439.300048828125,2434.050048828125,2441.949951171875,2455.0,2454.550048828125,2440.25,2439.949951171875,2506.5,2520.60009765625,2519.949951171875,2469.89990234375,2463.25,2455.199951171875,2477.25,2479.35009765625,2498.14990234375,2499.64990234375,2481.949951171875,2484.14990234375,2520.85009765625,2551.85009765625,2552.550048828125,2577.39990234375,2551.800048828125,2557.10009765625,2564.300048828125,2535.5,2514.75,2495.550048828125,2496.449951171875,2496.449951171875,2550.25,2615.699951171875,2588.75,2584.5,2638.75,2633.60009765625],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>RELIANCE = -0.491221 * HDFCBANK.NS + 3278.85<br>R<sup>2</sup>=0.047531<br><br>HDFCBANK.NS=%{x}<br>RELIANCE=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1582.050048828125,1599.4000244140625,1600.800048828125,1601.75,1602.75,1603.5,1604.0,1604.1500244140625,1604.4000244140625,1606.5,1607.5,1607.699951171875,1608.699951171875,1609.5999755859375,1610.5999755859375,1610.8499755859375,1615.800048828125,1615.800048828125,1625.6500244140625,1635.5,1635.550048828125,1635.5999755859375,1636.75,1637.199951171875,1638.449951171875,1641.050048828125,1643.5,1643.5999755859375,1644.449951171875,1644.5,1645.0,1646.9000244140625,1647.300048828125,1652.0999755859375,1653.199951171875,1658.449951171875,1658.5999755859375,1658.5999755859375,1659.5999755859375,1660.4000244140625,1663.300048828125,1664.1500244140625,1665.699951171875,1666.6500244140625,1667.800048828125,1671.800048828125,1671.9000244140625,1673.300048828125,1674.5999755859375,1675.0,1675.800048828125,1681.0,1684.9000244140625,1687.25,1687.5999755859375,1688.1500244140625,1692.449951171875,1693.1500244140625,1701.4000244140625,1719.800048828125,1727.800048828125,1728.199951171875],"xaxis":"x","y":[2501.71041 ...

# %% [markdown]
# Stock Market Performance Analysis: Overview and Tasks Performed
#
# 1. Stock market performance analysis is used to analyze historical stock price data, identify opportunities and risks, and make informed investment decisions.
# 2. The analysis involves collecting real-time stock market data using the Yahoo Finance API.
# 3. The dataset consists of historical stock price data for companies like Hdfc bank, Reliance, T.C.S, and Hindunilvr.
# 4. Data visualization is performed using line and area charts to visualize the stock market performance of the companies over the last three months.
# 5. Moving averages are calculated to identify trends and patterns in each company's stock price movements.
# 6. The moving averages are visualized to observe the crossover points and identify bullish or bearish signals.
# 7. Volatility is measured by calculating the percentage change in stock prices and rolling standard deviation.
# 8. The volatility of all companies is visualized using a line chart to observe the fluctuations in stock prices.
# 9. Correlation analysis is conducted between the stock prices of Hdfc Bank and Reliance to identify any relationship or similarity between them.
# 10. The correlation is visualized using a scatter plot with a trendline to show the strength and direction of the relationship.
#
# Tasks performed:
# - Importing necessary Python libraries and downloading historical stock price data.
# - Resetting the index of the dataset for further analysis.
# - Visualizing stock market performance using line and area charts.
# - Calculating and visualizing moving averages for each company.
# - Measuring and visualizing volatility of stock prices.
# - Conducting correlation analysis between Apple and Microsoft stock prices.
